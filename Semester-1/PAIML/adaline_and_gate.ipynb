# %%
# Define initial weights, bias, learning rate and points for Adaline
eta = 0.25  # Learning rate

# Initial weights and bias
w1, w2, B = 0.1, 0.1, 0.1

# Points and their target values
data = [
    {'X1': 1, 'X2': 1,  'T': 1},    # I1
    {'X1': 1, 'X2': -1, 'T': -1},   # I2
    {'X1': -1, 'X2': 1, 'T': -1},   # I3
    {'X1': -1, 'X2': -1, 'T': -1},   # I4
    {'X1': 1, 'X2': 1, 'T': 1},    # I1 (repeat of a point)
    {'X1': 1, 'X2': -1, 'T': -1},    # I2 (repeat)
    {'X1': -1, 'X2': 1, 'T': -1},    # I3 (repeat)
    {'X1': -1, 'X2': -1, 'T': -1}, # I4 (repeat)
    {'X1': 1, 'X2': 1, 'T': 1},    # I1 (repeat of a point)
    {'X1': 1, 'X2': -1, 'T': -1},    # I2 (repeat)
    {'X1': -1, 'X2': 1, 'T': -1},    # I3 (repeat)
    {'X1': -1, 'X2': -1, 'T': -1},
    {'X1': 1, 'X2': 1, 'T': 1},    # I1 (repeat of a point)
    {'X1': 1, 'X2': -1, 'T': -1},    # I2 (repeat)
    {'X1': -1, 'X2': 1, 'T': -1},    # I3 (repeat)
    {'X1': -1, 'X2': -1, 'T': -1},
    {'X1': 1, 'X2': 1, 'T': 1},    # I1 (repeat of a point)
    {'X1': 1, 'X2': -1, 'T': -1},    # I2 (repeat)
    {'X1': -1, 'X2': 1, 'T': -1},    # I3 (repeat)
    {'X1': -1, 'X2': -1, 'T': -1}
    ]

# List to store the outputs
results = []

# Function to calculate Adaline updates
def adaline_update(w1, w2, B, X1, X2, T, eta):
    # Predict Y_in
    Y_in = X1 * w1 + X2 * w2 + B
    
    # Calculate the error
    error = T - Y_in
    
    # Update weights and bias
    w1_new = w1 + eta * error * X1
    w2_new = w2 + eta * error * X2
    B_new = B + eta * error
    
    # Return the updated weights, bias, and the error
    return w1_new, w2_new, B_new, Y_in, error

# Apply Adaline for each point
for point in data:
    X1, X2, T = point['X1'], point['X2'], point['T']
    
    # Get updated weights, bias, prediction and error
    w1, w2, B, Y_in, error = adaline_update(w1, w2, B, X1, X2, T, eta)
    
    # Store the results for each iteration
    results.append({
        'X1': X1, 'X2': X2, 'T': T, 'Y_in': Y_in, 'Error': error,
        'Updated w1': w1, 'Updated w2': w2, 'Updated B': B
    })

results
# Out:
# [{'X1': 1,
#   'X2': 1,
#   'T': 1,
#   'Y_in': 0.30000000000000004,
#   'Error': 0.7,
#   'Updated w1': 0.275,
#   'Updated w2': 0.275,
#   'Updated B': 0.275},
#  {'X1': 1,
#   'X2': -1,
#   'T': -1,
#   'Y_in': 0.275,
#   'Error': -1.275,
#   'Updated w1': -0.043749999999999956,
#   'Updated w2': 0.59375,
#   'Updated B': -0.043749999999999956},
#  {'X1': -1,
#   'X2': 1,
#   'T': -1,
#   'Y_in': 0.59375,
#   'Error': -1.59375,
#   'Updated w1': 0.35468750000000004,
#   'Updated w2': 0.1953125,
#   'Updated B': -0.44218749999999996},
#  {'X1': -1,
#   'X2': -1,
#   'T': -1,
#   'Y_in': -0.9921875,
#   'Error': -0.0078125,
#   'Updated w1': 0.35664062500000004,
#   'Updated w2': 0.197265625,
#   'Updated B': -0.44414062499999996},
#  {'X1': 1,
#   'X2': 1,
#   'T': 1,
#   'Y_in': 0.10976562500000009,
#   'Error': 0.8902343749999999,
#   'Updated w1': 0.57919921875,
#   'Updated w2': 0.41982421875,
#   'Updated B': -0.22158203124999998},
#  {'X1': 1,
#   'X2': -1,
#   'T': -1,
#   'Y_in': -0.06220703124999993,
#   'Error': -0.9377929687500001,
#   'Updated w1': 0.3447509765625,
#   'Updated w2': 0.6542724609375,
#   'Updated B': -0.4560302734375},
#  {'X1': -1,
#   'X2': 1,
#   'T': -1,
#   'Y_in': -0.14650878906249998,
#   'Error': -0.8534912109375,
#   'Updated w1': 0.558123779296875,
#   'Updated w2': 0.44089965820312504,
#   'Updated B': -0.669403076171875},
#  {'X1': -1,
#   'X2': -1,
#   'T': -1,
#   'Y_in': -1.668426513671875,
#   'Error': 0.668426513671875,
#   'Updated w1': 0.3910171508789062,
#   'Updated w2': 0.2737930297851563,
#   'Updated B': -0.5022964477539062},
#  {'X1': 1,
#   'X2': 1,
#   'T': 1,
#   'Y_in': 0.16251373291015625,
#   'Error': 0.8374862670898438,
#   'Updated w1': 0.6003887176513671,
#   'Updated w2': 0.48316459655761723,
#   'Updated B': -0.2929248809814453},
#  {'X1': 1,
#   'X2': -1,
#   'T': -1,
#   'Y_in': -0.1757007598876954,
#   'Error': -0.8242992401123046,
#   'Updated w1': 0.394313907623291,
#   'Updated w2': 0.6892394065856934,
#   'Updated B': -0.49899969100952146},
#  {'X1': -1,
#   'X2': 1,
#   'T': -1,
#   'Y_in': -0.20407419204711907,
#   'Error': -0.7959258079528809,
#   'Updated w1': 0.5932953596115113,
#   'Updated w2': 0.4902579545974731,
#   'Updated B': -0.6979811429977417},
#  {'X1': -1,
#   'X2': -1,
#   'T': -1,
#   'Y_in': -1.781534457206726,
#   'Error': 0.781534457206726,
#   'Updated w1': 0.39791174530982976,
#   'Updated w2': 0.2948743402957916,
#   'Updated B': -0.5025975286960602},
#  {'X1': 1,
#   'X2': 1,
#   'T': 1,
#   'Y_in': 0.19018855690956116,
#   'Error': 0.8098114430904388,
#   'Updated w1': 0.6003646060824395,
#   'Updated w2': 0.49732720106840134,
#   'Updated B': -0.3001446679234505},
#  {'X1': 1,
#   'X2': -1,
#   'T': -1,
#   'Y_in': -0.19710726290941238,
#   'Error': -0.8028927370905876,
#   'Updated w1': 0.39964142180979256,
#   'Updated w2': 0.6980503853410482,
#   'Updated B': -0.5008678521960974},
#  {'X1': -1,
#   'X2': 1,
#   'T': -1,
#   'Y_in': -0.20245888866484174,
#   'Error': -0.7975411113351583,
#   'Updated w1': 0.5990266996435821,
#   'Updated w2': 0.4986651075072587,
#   'Updated B': -0.700253130029887},
#  {'X1': -1,
#   'X2': -1,
#   'T': -1,
#   'Y_in': -1.797944937180728,
#   'Error': 0.7979449371807279,
#   'Updated w1': 0.39954046534840015,
#   'Updated w2': 0.2991788732120767,
#   'Updated B': -0.500766895734705},
#  {'X1': 1,
#   'X2': 1,
#   'T': 1,
#   'Y_in': 0.19795244282577185,
#   'Error': 0.8020475571742282,
#   'Updated w1': 0.6000523546419572,
#   'Updated w2': 0.4996907625056337,
#   'Updated B': -0.300255006441148},
#  {'X1': 1,
#   'X2': -1,
#   'T': -1,
#   'Y_in': -0.19989341430482455,
#   'Error': -0.8001065856951755,
#   'Updated w1': 0.4000257082181633,
#   'Updated w2': 0.6997174089294276,
#   'Updated B': -0.5002816528649419},
#  {'X1': -1,
#   'X2': 1,
#   'T': -1,
#   'Y_in': -0.2005899521536776,
#   'Error': -0.7994100478463224,
#   'Updated w1': 0.5998782201797439,
#   'Updated w2': 0.49986489696784697,
#   'Updated B': -0.7001341648265225},
#  {'X1': -1,
#   'X2': -1,
#   'T': -1,
#   'Y_in': -1.7998772819741133,
#   'Error': 0.7998772819741133,
#   'Updated w1': 0.39990889968621557,
#   'Updated w2': 0.29989557647431864,
#   'Updated B': -0.5001648443329941}]
